# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Changing some IPython settings:
pd.set_option('display.max_columns', 32)

#Reading in the data:
teams = pd.read_csv('teams.csv', index_col = [0])
games = pd.read_csv('games.csv',index_col = False, parse_dates = [1])
players = pd.read_csv('players.csv', index_col = False)
gameStats = pd.read_csv('gameStats.csv', index_col = False, parse_dates = [2])

games.index = games.game_id

# %%
games.to_csv('games_new.csv', index = False)
players.to_csv('players_new.csv', index = False)
gameStats.to_csv('gameStats_new.csv', index = False)

# %%
#Statistics in gameStats data frame:
stats1 = ['date','season', 'team','team_id','home_01','win_01','PTSF','PTSA']
stats2 = ['AST', 'BLK', 'DREB', 'OREB', 'REB', 'MIN', 'PF', 'STL', 'TO', '3PM', '3PA', 'FGM', 'FGA', 'FTM', 'FTA', '+/-']
stats3 = ['PTS_diff', 'PACE', 'AST_ratio','DEF_eff','OFF_eff','FGP_adj','TO_rate','DREB_p','OREB_p','FT_rate']

# %%
#Doing some scatter plot analysis:
import matplotlib.pyplot as plt
# %matplotlib inline

x = gameStats.AST
y = gameStats.PTS_diff
plt.scatter(x,y)

# %%
#Doing some distribution analysis:
gameStats.FT_rate.hist(bins = 50)

# %%
#Looking at yearly trends of game statistics:
df = gameStats.groupby('season').mean()
df = df[df.index != 2012] #Taking out the season during which the lockout occured
df
# Out:
#           game_id    team_id  win_01        PTSF        PTSA        AST  \
# season
# 2005    247119861  14.489300     0.5   97.136214   97.136214  21.250206
# 2006    257049913  14.487644     0.5   96.981466   96.981466  20.611203
# 2007    266915131  14.469824     0.5   98.743923   98.743923  21.268231
# 2008    276809740  14.517471     0.5   99.888519   99.888519  21.725874
# 2009    286744467  14.537798     0.5   99.884552   99.884552  20.957272
# 2010    296741154  14.511410     0.5  100.466585  100.466585  21.248574
# 2011    306680262  14.516300     0.5   99.557457   99.557457  21.496333
# 2012    319741278  14.498974     0.5   96.252308   96.252308  20.960000
# 2013    400278593  14.522838     0.5   98.134176   98.134176  22.134992
# 2014    400489556  14.508550     0.5  101.019544  101.019544  22.011401
# 2015    400578993  14.510738     0.5   99.883754   99.883754  21.969655
#
#              BLK       DREB       OREB        REB         MIN         PF  \
# season
# ...

# %%
foo = df.FT_rate
foo.plot()

# %%
#Looking at season-level trends of game statistics:
df = gameStats.set_index('date')
df = df.drop('+/-',1)
df = df.resample('2W', how = 'mean')
df = df.dropna()
df.head()
# Out:
#                  game_id  season    team_id  win_01       PTSF       PTSA  \
# date
# 2004-11-07  2.411046e+08    2005  14.613636     0.5  95.397727  95.397727
# 2004-11-21  2.411147e+08    2005  14.648515     0.5  95.871287  95.871287
# 2004-12-05  2.411539e+08    2005  14.715686     0.5  95.151961  95.151961
# 2004-12-19  2.412121e+08    2005  14.510101     0.5  95.378788  95.378788
# 2005-01-02  2.425673e+08    2005  14.482558     0.5  97.500000  97.500000
#
#                   AST       BLK       DREB       OREB        REB         MIN  \
# date
# 2004-11-07  20.806818  5.772727  29.534091  12.738636  42.272727  243.261364
# 2004-11-21  21.188119  4.930693  29.717822  12.039604  41.757426  243.004950
# 2004-12-05  20.656863  4.828431  29.897059  11.901961  41.799020  241.720588
# 2004-12-19  20.858586  4.949495  29.959596  12.555556  42.515152  242.858586
# 2005-01-02  21.610465  4.843023  29.267442  12.046512  41.313953  240.773256
#
# ...

# %%
foo = df.loc[(boom.season == 2014) , 'FGP_adj'] 
foo.plot()
